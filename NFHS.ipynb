# %% [markdown]
# <a href="https://colab.research.google.com/github/beingrealnishtha27-commits/codsoft/blob/main/NFHS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 32.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['SheCares', 'Colab Notebooks']

# %%
os.listdir('/content/drive/MyDrive/SheCares/')
# Out:
# ['datasets raw',
#  'datasets cleaned',
#  'models saved_models',
#  'models results',
#  'figures ',
#  'references ',
#  'Info',
#  'dhs',
#  'Research paper summary']

# %%
os.listdir('/content/drive/MyDrive/SheCares/dhs/')
# Out:
# ['IAIR7EFL.DOCX',
#  'IAIR7EFL.DCT',
#  'IAIR7EFL.DO',
#  'IAIR7EFL.DTA',
#  'IAIR7EFL.FRQ',
#  'IAIR7EFL.FRW',
#  'IAIR7EFL.MAP',
#  'dataset_preview.csv',
#  'column_names.txt',
#  'view_dataset.py',
#  'labeled_dataset_first_5_rows.csv',
#  'summarize_nfhs.py']

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/SheCares/dhs/IAIR7EFL.DTA'

df = pd.read_stata(file_path,
                   columns=["v012", "v024", "v025", "v215"],
                   convert_categoricals=True)

# Figure 1 — Age distribution
plt.figure(figsize=(10, 5))
df["v012"].hist(bins=35, color="mediumpurple")
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Indian Women (NFHS-5)")
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_age_distribution.png", dpi=150)
plt.close()
print("Figure 1 done")

# Figure 2 — Rural vs Urban
plt.figure(figsize=(6, 5))
df["v025"].value_counts().plot(kind="bar", color=["steelblue", "coral"])
plt.title("Rural vs Urban Split (NFHS-5)")
plt.ylabel("Number of Women")
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_rural_urban.png", dpi=150)
plt.close()
print("Figure 2 done")

# Figure 3 — Top 10 states
plt.figure(figsize=(12, 5))
df["v024"].value_counts().head(10).plot(kind="bar", color="teal")
plt.title("Top 10 States Represented (NFHS-5)")
plt.ylabel("Number of Women")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_top_states.png", dpi=150)
plt.close()
print("Figure 3 done")

# Stats for paper
print("\nTotal women surveyed:", len(df))
print("\nAge stats:")
print(df["v012"].describe())
print("\nResidence split (%):")
print(df["v025"].value_counts(normalize=True) * 100)
print("\nTop 5 states:")
print(df["v024"].value_counts().head(5))

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/SheCares/dhs/IAIR7EFL.DTA'

# Load only 4 columns instead of entire file
df = pd.read_stata(file_path,
                   columns=["v012", "v024", "v025"],
                   convert_categoricals=True)

print("File loaded successfully!")
print("Shape:", df.shape)
print(df.head())

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/SheCares/dhs/IAIR7EFL.DTA'

# Load only first 50000 rows to test
df = pd.read_stata(file_path,
                   columns=["v012", "v024", "v025"],
                   convert_categoricals=True,
                   chunksize=50000)

# Take only first chunk
df = next(iter(df))
print("Loaded successfully!")
print("Shape:", df.shape)
print(df.head())
# Out:
# Loaded successfully!
# Shape: (50000, 3)
#    v012             v024   v025
# 0    22  jammu & kashmir  rural
# 1    19  jammu & kashmir  rural
# 2    38  jammu & kashmir  rural
# 3    40  jammu & kashmir  rural
# 4    22  jammu & kashmir  rural

# %%
import matplotlib.pyplot as plt

# Figure 1 — Age distribution
plt.figure(figsize=(10, 5))
df["v012"].hist(bins=35, color="mediumpurple")
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Indian Women (NFHS-5)")
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_age_distribution.png", dpi=150)
plt.close()
print("Figure 1 done ✅")

# Figure 2 — Rural vs Urban
plt.figure(figsize=(6, 5))
df["v025"].value_counts().plot(kind="bar", color=["steelblue", "coral"])
plt.title("Rural vs Urban Split (NFHS-5)")
plt.ylabel("Number of Women")
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_rural_urban.png", dpi=150)
plt.close()
print("Figure 2 done ✅")

# Figure 3 — Top 10 states
plt.figure(figsize=(12, 5))
df["v024"].value_counts().head(10).plot(kind="bar", color="teal")
plt.title("Top 10 States Represented (NFHS-5)")
plt.ylabel("Number of Women")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/SheCares/figures /nfhs_top_states.png", dpi=150)
plt.close()
print("Figure 3 done ✅")

# Stats for paper
print("\nTotal rows used:", len(df))
print("\nAge stats:")
print(df["v012"].describe())
print("\nResidence split (%):")
print(df["v025"].value_counts(normalize=True) * 100)
print("\nTop 5 states:")
print(df["v024"].value_counts().head(5))
# Out:
# Figure 1 done ✅
# Figure 2 done ✅
# Figure 3 done ✅
#
# Total rows used: 50000
#
# Age stats:
# count    50000.000000
# mean        30.927260
# std          9.614864
# min         15.000000
# 25%         23.000000
# 50%         30.000000
# 75%         39.000000
# max         49.000000
# Name: v012, dtype: float64
#
# Residence split (%):
# v025
# rural    79.522
# urban    20.478
# Name: proportion, dtype: float64
#
# Top 5 states:
# v024
# jammu & kashmir     23037
# punjab              16595
# himachal pradesh    10368
# chandigarh              0
# uttarakhand             0
# Name: count, dtype: int64

# %%
import os
os.listdir('/content/drive/MyDrive/SheCares/figures /')
# Out:
# ['dtw_distances.png',
#  'ocsvm_scores.png',
#  'roc_classical.png',
#  'rf_confusion_matrix.png',
#  'rf_feature_importance.png',
#  'rf_roc_curve.png',
#  'nfhs_age_distribution.png',
#  'nfhs_rural_urban.png',
#  'nfhs_top_states.png']
